# %% [markdown]
# # Подготовка среды исполнения программы

# %%
# Тест установленной версии pip и python
# !pip --version
# !python --version

# %%
# Тест доступа к файловой системе хост-машины, в которую клонируется гит репозиторий и в которой размещается мигрированный из Студии проект
# !cd ./gitlab && ls -F

# %% [markdown]
# ## Определение и инициализация используемых функций
# Импортируются используемые библиотеки
#
# Инициализируются константы
#
# Инициализируются функции def ...()

# %%
# %run functions.ipynb

# %load_ext nb_black

# %% [markdown]
# ## Константы

# %%
# Структура папок
# WORKSPACE_DIR/exp-03-supp/ - папка клонированного гит репозитория
# WORKSPACE_DIR/migration/
#                   exp-03-supp/ - папка импортированного проекта
#                   exp-03-supp(backup).zip - бэкапим импортированный проект на всякий случай

# Мапинг папок указывается в файле docker-compose.yml как 
# volumes:
#     - ~/GitLab:/workspace/gitlab
# ~/GitLab - папка на файловой системе хост-машины, в которую клонируется гит репозиторий и в которой размещается мигрированный из Студии проект
# /workspace/gitlab - папка на файловой системе docker-контейнера, путь доступа к данным из этого блокнота
WORKSPACE_DIR = './gitlab/'
GIT_DIR = f'{WORKSPACE_DIR}exp-03-supp/'
MIG_DIR = f'{WORKSPACE_DIR}migration/exp-03-supp/' 
# MIG_DIR = f'{WORKSPACE_DIR}migration/REF/' # папка импортированной бинарной сборки
GIT_DOCS_DIR = f'{GIT_DIR}Func/docs/'
MIG_DOCS_DIR = f'{MIG_DIR}Func/docs/'
GIT_LC_DIR = f'{GIT_DIR}Func/config/lifecycles/'
MIG_LC_DIR = f'{MIG_DIR}Func/config/lifecycles/'
NAVIGATION_DIR = f'{GIT_DIR}Func/config/sufd-interface/setup/navigation/default.navigation'

# %% [markdown]
# ## Миграция формуляров
# Файлы desc и другие имеющиеся в папке формуляра файлы копируются в гит папку формуляра

# %%
# ВНИМАНИЕ! Копирование desc, counter, edit и др файлов из папки мигрируемого формуляра в папку гит формуляра
copy_file_to_git(
    prepare_df2()
)

# %%
# Тест
# Получение окончательного набора формуляров для копирования
# Автоматизировано получение списка формуляров из навигации
# Автоматизировано исключение из списка неподходящих формуляров: для ручного копирования, для поиска в бинарках
# Автоматизировано добавление в список известных базовых формуляров: {'DOC_BASE.desc', 'DOC_BASE.ext.desc', 'DICT_BASE.desc', 'DICT_BASE.ext.desc', 'REPORT_BASE.desc', 'REPORT_BASE.ext.desc'}
# Автоматизировано исключение из списка базовых формуляров тех, которых нет в мигрируемом проекте
# Автоматизировано решение конфликта с дублями формуляров в гите: из двух остается максимально близкий по размеру к мигрируемому формуляру
prepare_df2()
# Out:
#                          formular  size_x  \
# 0        EXP_ListBOInventory.desc    5578
# 1        DBD_NoticeUnmarkDSP.desc   45349
# 2    VLS_RequestDisableContr.desc   57650
# 4                MSC_InfoDoc.desc   21127
# 5               EXP_InfAbout.desc    7682
# ..                            ...     ...
# 174      EXP_ExcangeRate.ext.desc    7514
# 175       MSC_RiskGroupRules.desc   19983
# 176      DBD_InteractSystems.desc   21838
# 177                 EXP_GRBS.desc    4706
# 178       EXP_ReasonsRefusal.desc   16359
#
#                                                 path_x  size_y  \
# 0    ./migration/exp-03-supp/Func/docs/sufd-service...    1667
# 1    ./migration/exp-03-supp/Func/docs/sufd-service...    9282
# 2    ./migration/exp-03-supp/Func/docs/sufd-service...   11112
# 4    ./migration/exp-03-supp/Func/docs/sufd-service...    4371
# 5    ./migration/exp-03-supp/Func/docs/sufd-service...    2242
# ..                                                 ...     ...
# 174  ./migration/exp-03-supp/Func/docs/sufd-service...    1559
# 175  ./migration/exp-03-supp/Func/docs/sufd-service...    3598
# 176  ./migration/exp-03-supp/Func/docs/sufd-service...    4183
# 177  ./migration/exp-03-supp/Func/docs/sufd-service...    1356
# 178  ./migration/exp-03-supp/Func/docs/sufd-service...    3554
#
#                                                 path_y
# 0    ./exp-03-supp/Func/docs/sufd-services.EXP/setu...
# 1    ./exp-03-supp/Func/docs/sufd-services.EXP/setu...
# 2    ./exp-03-supp/Func/docs/sufd-services.EXP/setu...
# 4    ./exp-03-supp/Func/docs/sufd-services.EXP/setu...
# 5    ./exp-03-supp/Func/docs/sufd-services.EXP/setu...
# ..                                                 ...
# 174  ./exp-03-supp/Func/docs/sufd-services.CostMana...
# 175  ./exp-03-supp/Func/docs/sufd-services.dicts/se...
# 176  ./exp-03-supp/Func/docs/sufd-services.dicts/se...
# 177  ./exp-03-supp/Func/docs/sufd-services.dicts/se...
# 178  ./exp-03-supp/Func/docs/sufd-services.dicts/se...
#
# [170 rows x 5 columns]

# %%
# Тест
# Проверить отсутствие в списке для exp-03-supp
# DBD_Approval_Solution.desc -- calc_navigation_df('nav_to_full_copy')
# EXP_FAIP.ext.desc -- calc_navigation_df('to_manual_copy')
prepare_df2().loc[lambda x: x.formular == 'EXP_ListBOInventory.desc']
# Out:
#                    formular  size_x  \
# 0  EXP_ListBOInventory.desc    5578
#
#                                               path_x  size_y  \
# 0  ./migration/exp-03-supp/Func/docs/sufd-service...    5578
#
#                                               path_y
# 0  ./exp-03-supp/Func/docs/sufd-services.EXP/setu...

# %% [markdown]
# ## Обработка массива ЖЦ

# %%
# ВНИМАНИЕ! Изменение всех жц!
batch_lc(
    prepare_lc_df('nav_to_copy','lc_to_copy')
)

# %%
# Тест
# Получение окончательного списка ЖЦ для копирования
# Автоматизировано получение списка формуляров из навигации и получение их ЖЦ
# Автоматизировано добавление в список родительских ЖЦ из всех ЖЦ гит проекта
prepare_lc_df('nav_to_copy','lc_to_copy')

# %%
# Тест нахождения конкретного ЖЦ в изменяемых файлах
prepare_lc_df('nav_to_copy','lc_to_copy').loc[lambda x: x.lc == 'MSC_AccountTrans_lc.lc']
# Out:
#                         lc  size_x  \
# 62  MSC_AccountTrans_lc.lc    5366
#
#                                                path_x  size_y  \
# 62  ./Func/config/lifecycles/MSC_AccountTrans_lc/M...    4798
#
#                                                path_y
# 62  ../../exp-03-supp/Func/config/lifecycles/MSC_A...

# %% [markdown]
# # Анализ формуляров проекта
# Одноименные, но расположенные в разных сервисах в гите и в мигрируемом из Студии проекте
#
# Дубликаты
#
# Новые формуляры, которые есть только в мигрируеом проекте и которых нет в гите
#
# Соответствие модели desc/ext.desc у формуляров в гите и в мигрируемом проекте

# %%
print_files_amount('git',['.desc'])
print_files_amount('migration',['.desc'])
# Out:
# Всего файлов ['.desc'] в проекте git: 620
# Всего файлов ['.desc'] в проекте migration: 285

# %% [markdown]
# ## Результаты анализа
# Уникальные - нет совпадений по имени формуляра в мигрируемом проекте и в гите, надо искать совпадения в бинарных сборках или других проектах.
#
# Одноименные - есть совпадение по имени формуляра в мирируемом проекте и в гите, можно выгружать по стандартному сценарию.
#
# Новые - новые для гита, надо выгружать по полному сценарию.

# %%
print('Найдено уникальных формуляров проекта:')
print(len(get_pre_set('difference')))
print('Найдено одноименных формуляров проекта: ')
print(len(get_pre_set('the_same')))
print('Найдено новых для гита формуляров в мигрируемом проекте: ')
print(len(get_pre_set('new_to_git')))
get_pre_set('new_to_git')
# Out:
# Найдено уникальных формуляров проекта:
# 370
# Найдено одноименных формуляров проекта:
# 257
# Найдено новых для гита формуляров в мигрируемом проекте:
# 28
# {'DBD_Approval_Solution.desc',
#  'DBD_DetailedProtocol.desc',
#  'DBD_ProtocolControlTN.desc',
#  'DBD_REPORT_50.desc',
#  'DBD_Report_GRBS.desc',
#  'DBD_ResInfProc.desc',
#  'DBD_test_formular.desc',
#  'EXP_FAIP.ext.desc',
#  'MSC_ANSFOREQUEST.desc',
#  'MSC_BO_OBL.desc',
#  'MSC_BO_OBSD.desc',
#  'MSC_BO_OBT.desc',
#  'MSC_CLIENTREPORTREQUEST.desc',
#  'MSC_DACH.desc',
#  'MSC_KOOBANK.desc',
#  'MSC_LETTEROFKOOBANK.desc',
#  'MSC_PayDoc.desc',
#  'MSC_REGISTRYINFO.desc',
#  'MSC_REPORTS.desc',
#  'MSC_REQ_CAFK.desc',
#  'MSC_ReqTest.desc',
#  'MSC_ZON.desc',
#  'VLS_REPORT_0531754.desc',
#  'VLS_REPORT_0531785.desc',
#  'VLS_REPORT_ACC_STATE.desc',
#  'VLS_REPORT_BD_POFR.desc',
#  'VLS_REPORT_INF_LBO_GRBS.desc',
#  'qwqew.desc'}

# %%
# Проверка на уникальность
print('Всего формуляров в гит')
print(len(get_pre_set('git_total')))
print('Уникальных формуляров в гит')
print(len(get_pre_set('git_unique')))
# Out:
# Всего формуляров в гит
# 620
# Уникальных формуляров в гит
# 599

# %%
# Список дублируемых формуляров в клонированном гит репозитории
print(len(get_pre_set('duplicated')))
get_pre_set('duplicated')
# Out:
# 21
# {'ARP_REPORT_ACCLS.desc',
#  'EXP_Receipt.desc',
#  'EXP_RegisPublicServices.ext.desc',
#  'MSC_AcntTransaction.desc',
#  'MSC_ApplCash.ext.desc',
#  'MSC_ApplCashFlow.ext.desc',
#  'MSC_ApplCashFlowShrt.ext.desc',
#  'MSC_ApplFundsCard.ext.desc',
#  'MSC_ApplRefund.ext.desc',
#  'MSC_ExpendableSchedule.ext.desc',
#  'MSC_InfoDoc.desc',
#  'MSC_NoticeClarOper.ext.desc',
#  'MSC_NoticeClarTypePay.ext.desc',
#  'MSC_NoticeExcBO.desc',
#  'MSC_PaymentOrder.ext.desc',
#  'MSC_PaymentOrderFK.ext.desc',
#  'MSC_ReceiptPUR_EB.ext.desc',
#  'MSC_SumApplCashFlowTax.ext.desc',
#  'MSC_TOFKRegisterMonitor.desc',
#  'REF_LegalActType.ext.desc',
#  'REF_PersAccount.ext.desc'}

# %%
# Вывод в формате: файл, размер(байт), путь
simple_print_file_path(get_pre_set('duplicated'))
# Out:
# ['MSC_AcntTransaction.desc', 29270, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_AcntTransaction/1.0/MSC_AcntTransaction.desc']
# ['MSC_AcntTransaction.desc', 4643, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_AcntTransaction/1.0/MSC_AcntTransaction.desc']
# ['MSC_AcntTransaction.desc', 29270, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_AcntTransaction/1.0/MSC_AcntTransaction.desc']
# ['MSC_NoticeClarOper.ext.desc', 49045, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_NoticeClarOper/1.0/MSC_NoticeClarOper.ext.desc']
# ['MSC_NoticeClarOper.ext.desc', 8568, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_NoticeClarOper/1.0/MSC_NoticeClarOper.ext.desc']
# ['MSC_NoticeClarOper.ext.desc', 49045, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_NoticeClarOper/1.0/MSC_NoticeClarOper.ext.desc']
# ['EXP_Receipt.desc', 11353, './migration/exp-03-supp/Func/docs/sufd-services.EXP/EXP_Receipt/1.0/EXP_Receipt.desc']
# ['EXP_Receipt.desc', 2591, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/EXP_Receipt/1.0/EXP_Receipt.desc']
# ['EXP_Receipt.desc', 11353, './exp-03-supp/Func/docs/sufd-services.EXP/setup/EXP_Receipt/1.0/EXP_Receipt.desc']
# ['MSC_ApplRefund.ext.desc', 268765, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_ApplRefund/1.0/MSC_ApplRefund.ext.desc']
# ['MSC_ApplRefund.ext.desc', 9040, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_ApplRefund/1.0/MSC_ApplRefund.ext.desc']
# ['MSC_ApplRefund.ext.desc', 51313, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_ApplRefund/1.0/MSC_ApplRefund.ext.desc']
# ['MSC_ApplCash.ext.desc', 260411, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_ApplCash/1.0/MSC_ApplCash.ext.desc']
# ['MSC_ApplCash.ext.desc', 7989, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_ApplCash/1.0/MSC_ApplCash.ext.desc']
# ['MSC_ApplCash.ext.desc', 48857, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_ApplCash/1.0/MSC_ApplCash.ext.desc']
# ['EXP_RegisPublicServices.ext.desc', 254316, './migration/exp-03-supp/Func/docs/sufd-services.EXP/EXP_RegisPublicServices/1.0/EXP_RegisPublicServices.ext.desc']
# ['EXP_RegisPublicServices.ext.desc', 254316, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/EXP_RegisPublicServices/1.0/EXP_RegisPublicServices.ext.desc']
# ['EXP_RegisPublicServices.ext.desc', 75118, './exp-03-supp/Func/docs/sufd-services.EXP/setup/EXP_RegisPublicServices/1.0/EXP_RegisPublicServices.ext.desc']
# ['MSC_NoticeExcBO.desc', 109168, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_NoticeExcBO/1.0/MSC_NoticeExcBO.desc']
# ['MSC_NoticeExcBO.desc', 16158, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_NoticeExcBO/1.0/MSC_NoticeExcBO.desc']
# ['MSC_NoticeExcBO.desc', 109168, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_NoticeExcBO/1.0/MSC_NoticeExcBO.desc']
# ['MSC_InfoDoc.desc', 21127, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_InfoDoc/1.0/MSC_InfoDoc.desc']
# ['MSC_InfoDoc.desc', 4289, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_InfoDoc/1.0/MSC_InfoDoc.desc']
# ['MSC_InfoDoc.desc', 21127, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_InfoDoc/1.0/MSC_InfoDoc.desc']
# ['MSC_TOFKRegisterMonitor.desc', 15293, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_TOFKRegisterMonitor/1.0/MSC_TOFKRegisterMonitor.desc']
# ['MSC_TOFKRegisterMonitor.desc', 3910, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_TOFKRegisterMonitor/1.0/MSC_TOFKRegisterMonitor.desc']
# ['MSC_TOFKRegisterMonitor.desc', 3860, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_TOFKRegisterMonitor/1.0/MSC_TOFKRegisterMonitor.desc']
# ['MSC_SumApplCashFlowTax.ext.desc', 252862, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_SumApplCashFlowTax/1.0/MSC_SumApplCashFlowTax.ext.desc']
# ['MSC_SumApplCashFlowTax.ext.desc', 8794, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_SumApplCashFlowTax/1.0/MSC_SumApplCashFlowTax.ext.desc']
# ['MSC_SumApplCashFlowTax.ext.desc', 48103, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_SumApplCashFlowTax/1.0/MSC_SumApplCashFlowTax.ext.desc']
# ['MSC_ApplFundsCard.ext.desc', 239024, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_ApplFundsCard/1.0/MSC_ApplFundsCard.ext.desc']
# ['MSC_ApplFundsCard.ext.desc', 6079, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_ApplFundsCard/1.0/MSC_ApplFundsCard.ext.desc']
# ['MSC_ApplFundsCard.ext.desc', 47082, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_ApplFundsCard/1.0/MSC_ApplFundsCard.ext.desc']
# ['MSC_PaymentOrder.ext.desc', 50361, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_PaymentOrder/1.0/MSC_PaymentOrder.ext.desc']
# ['MSC_PaymentOrder.ext.desc', 9433, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_PaymentOrder/1.0/MSC_PaymentOrder.ext.desc']
# ['MSC_PaymentOrder.ext.desc', 50361, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_PaymentOrder/1.0/MSC_PaymentOrder.ext.desc']
# ['REF_PersAccount.ext.desc', 5904, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_PersAccount/1.0/REF_PersAccount.ext.desc']
# ['REF_PersAccount.ext.desc', 18926, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_PersAccount/1.0/REF_PersAccount.ext.desc']
# ['MSC_ReceiptPUR_EB.ext.desc', 25477, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_ReceiptPUR_EB/1.0/MSC_ReceiptPUR_EB.ext.desc']
# ['MSC_ReceiptPUR_EB.ext.desc', 4205, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_ReceiptPUR_EB/1.0/MSC_ReceiptPUR_EB.ext.desc']
# ['MSC_ReceiptPUR_EB.ext.desc', 25477, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_ReceiptPUR_EB/1.0/MSC_ReceiptPUR_EB.ext.desc']
# ['MSC_NoticeClarTypePay.ext.desc', 246614, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_NoticeClarTypePay/1.0/MSC_NoticeClarTypePay.ext.desc']
# ['MSC_NoticeClarTypePay.ext.desc', 9850, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_NoticeClarTypePay/1.0/MSC_NoticeClarTypePay.ext.desc']
# ['MSC_NoticeClarTypePay.ext.desc', 48010, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_NoticeClarTypePay/1.0/MSC_NoticeClarTypePay.ext.desc']
# ['MSC_ExpendableSchedule.ext.desc', 245505, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_ExpendableSchedule/1.0/MSC_ExpendableSchedule.ext.desc']
# ['MSC_ExpendableSchedule.ext.desc', 12306, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_ExpendableSchedule/1.0/MSC_ExpendableSchedule.ext.desc']
# ['MSC_ExpendableSchedule.ext.desc', 49598, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_ExpendableSchedule/1.0/MSC_ExpendableSchedule.ext.desc']
# ['MSC_ApplCashFlowShrt.ext.desc', 278950, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_ApplCashFlowShrt/1.0/MSC_ApplCashFlowShrt.ext.desc']
# ['MSC_ApplCashFlowShrt.ext.desc', 11692, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_ApplCashFlowShrt/1.0/MSC_ApplCashFlowShrt.ext.desc']
# ['MSC_ApplCashFlowShrt.ext.desc', 52950, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_ApplCashFlowShrt/1.0/MSC_ApplCashFlowShrt.ext.desc']
# ['ARP_REPORT_ACCLS.desc', 94179, './migration/exp-03-supp/Func/docs/sufd-services.EXP/ARP_REPORT_ACCLS/1.0/ARP_REPORT_ACCLS.desc']
# ['ARP_REPORT_ACCLS.desc', 23416, './exp-03-supp/Func/docs/sufd-services.EXP/setup/ARP_REPORT_ACCLS/1.0/ARP_REPORT_ACCLS.desc']
# ['ARP_REPORT_ACCLS.desc', 13310, './exp-03-supp/Func/docs/sufd-services.dicts/setup/ARP_REPORT_ACCLS/1.0/ARP_REPORT_ACCLS.desc']
# ['REF_LegalActType.ext.desc', 981, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_LegalActType/1.0/REF_LegalActType.ext.desc']
# ['REF_LegalActType.ext.desc', 1026, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_LegalActType/1.0/REF_LegalActType.ext.desc']
# ['MSC_PaymentOrderFK.ext.desc', 52049, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_PaymentOrderFK/1.0/MSC_PaymentOrderFK.ext.desc']
# ['MSC_PaymentOrderFK.ext.desc', 9634, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_PaymentOrderFK/1.0/MSC_PaymentOrderFK.ext.desc']
# ['MSC_PaymentOrderFK.ext.desc', 52049, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_PaymentOrderFK/1.0/MSC_PaymentOrderFK.ext.desc']
# ['MSC_ApplCashFlow.ext.desc', 310478, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_ApplCashFlow/1.0/MSC_ApplCashFlow.ext.desc']
# ['MSC_ApplCashFlow.ext.desc', 11622, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/MSC_ApplCashFlow/1.0/MSC_ApplCashFlow.ext.desc']
# ['MSC_ApplCashFlow.ext.desc', 63311, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_ApplCashFlow/1.0/MSC_ApplCashFlow.ext.desc']

# %%
# Список дублируемых формуляров в мигрируемом проекте
print('Всего формуляров в мигрируемом проекте')
print(len(get_pre_set('migration_total')))
print('Уникальных формуляров в мигрируемом проекте')
print(len(get_pre_set('migration_unique')))
# Out:
# Всего формуляров в мигрируемом проекте
# 285
# Уникальных формуляров в мигрируемом проекте
# 285

# %%
# Формуляры из гита, которых нет в мигрированном из Студии2 проекте
print('Только гит(нет в мигрируемом проекте)')
print(len(get_pre_set('git_only')))
print('+ гит И есть в мигрируемом проект')
print(len(get_pre_set('the_same')))
print('+ дубли в гите')
print(len(get_pre_set('duplicated')))
print('ВСЕГО формуляров в гите')
print(len(get_pre_set('git_total')))
# Out:
# Только гит(нет в мигрируемом проекте)
# 342
# + гит И есть в мигрируемом проект
# 257
# + дубли в гите
# 21
# ВСЕГО формуляров в гите
# 620

# %%
#поиск формуляров правильно мигрированных
#на примере MSC_EXECUTIONKZA.desc
simple_print_file_path('MSC_EXECUTIONKZA.desc')
# Out:
# ['MSC_EXECUTIONKZA.desc', 116492, './migration/exp-03-supp/Func/docs/sufd-services.EXP/MSC_EXECUTIONKZA/1.0/MSC_EXECUTIONKZA.desc']
# ['MSC_EXECUTIONKZA.desc', 116492, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_EXECUTIONKZA/1.0/MSC_EXECUTIONKZA.desc']

# %% [markdown]
# # Анализ формуляров из default.navigation
# Для копирования из бинарок
#
# Для полного копирования из мигрированного проекта
#
# Для копирования вручную из-за несоотвествия моделей desc/ext.desc
#
# Для копирования по стандартному сценарию из мигрированного проекта
#
# Из них:
#
# Базовые формуляры для копирования из бинарок
#
# Базовые формуляры для копирования по стандартному сценарию из мигрированного проекта

# %% [markdown]
# ## Результаты анализа

# %%
print('Списки формуляров: для копирования из бинарок')
print(calc_navigation_df('nav_to_find_in_binary').shape)
print('для полного копирования из мигрированного проекта')
print(calc_navigation_df('nav_to_full_copy').shape)
print('для копирования вручную из-за несоотвествия моделей desc/ext.desc')
print(calc_navigation_df('to_manual_copy').shape)
print('для копирования по стандартному сценарию из мигрированного проекта')
print(calc_navigation_df('nav_to_copy').shape)
print()
print('Всего формуляров в навигации')
print(len(navigation_df(get_xml_root('navigation','nav_formular','navigation'))))
print('Базовые формуляры для копирования из бинарок')
print(calc_navigation_df('base_to_find_in_binary').shape)
print('Базовые формуляры для копирования по стандартному сценарию из мигрированного проекта')
print(calc_navigation_df('base_to_copy').shape)
# Out:
# Списки формуляров: для копирования из бинарок
# (52, 1)
# для полного копирования из мигрированного проекта
# (1, 1)
# для копирования вручную из-за несоотвествия моделей desc/ext.desc
# (1, 1)
# для копирования по стандартному сценарию из мигрированного проекта
# (170, 1)
#
# Всего формуляров в навигации
# 221
# Базовые формуляры для копирования из бинарок
# (1, 1)
# Базовые формуляры для копирования по стандартному сценарию из мигрированного проекта
# (2, 1)

# %%
# Список формуляров, которые есть в навигации и в гите, которых нет в мигрируемом проекте
# Формуляры для поиска в бинарных сборках
simple_print_file_path (
    get_set_from_df(
      calc_navigation_df('nav_to_find_in_binary')
    )
)
# Out:
# ['REF_OKV.ext.desc', 2408, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_OKV/1.0/REF_OKV.ext.desc']
# ['REF_OKATOtoOKTMO.ext.desc', 4725, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_OKATOtoOKTMO/1.0/REF_OKATOtoOKTMO.ext.desc']
# ['REF_KBK_NR.desc', 3223, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBK_NR/1.0/REF_KBK_NR.desc']
# ['ARP_DOCFORACC.desc', 4305, './exp-03-supp/Func/docs/sufd-services.dicts/setup/ARP_DOCFORACC/1.0/ARP_DOCFORACC.desc']
# ['REF_PASection.desc', 2603, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_PASection/1.0/REF_PASection.desc']
# ['REF_OKSM.ext.desc', 2179, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_OKSM/1.0/REF_OKSM.ext.desc']
# ['REF_CSandRC.desc', 1782, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_CSandRC/1.0/REF_CSandRC.desc']
# ['REF_KBK_30_Ist.ext.desc', 5615, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBK_30_Ist/1.0/REF_KBK_30_Ist.ext.desc']
# ['REF_TaxpayerStatuses.desc', 1742, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_TaxpayerStatuses/1.0/REF_TaxpayerStatuses.desc']
# ['REF_OKTMO.ext.desc', 2552, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_OKTMO/1.0/REF_OKTMO.ext.desc']
# ['REF_OKEI.ext.desc', 2670, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_OKEI/1.0/REF_OKEI.ext.desc']
# ['REF_BankAccount.desc', 7627, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_BankAccount/1.0/REF_BankAccount.desc']
# ['REPORT_BASE.desc', 8072, './exp-03-supp/Func/docs/sufd-services.UDUBUBU/setup/REPORT_BASE/1.0/REPORT_BASE.desc']
# ['REF_NationProject.desc', 2573, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_NationProject/1.0/REF_NationProject.desc']
# ['REF_AnaCodeIncSrc.desc', 2319, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_AnaCodeIncSrc/1.0/REF_AnaCodeIncSrc.desc']
# ['REF_EGRUL.ext.desc', 18086, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_EGRUL/1.0/REF_EGRUL.ext.desc']
# ['REF_BankCards.desc', 6607, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_BankCards/1.0/REF_BankCards.desc']
# ['DBD_ListInform.desc', 5453, './exp-03-supp/Func/docs/sufd-services.dicts/setup/DBD_ListInform/1.0/DBD_ListInform.desc']
# ['REF_KBKCCSS.ext.desc', 3306, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBKCCSS/1.0/REF_KBKCCSS.ext.desc']
# ['REF_KBK_10_Rashod.ext.desc', 4337, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBK_10_Rashod/1.0/REF_KBK_10_Rashod.ext.desc']
# ['MSC_MIRCardExecNt.desc', 10148, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_MIRCardExecNt/1.0/MSC_MIRCardExecNt.desc']
# ['REF_KBK_20_Dohod.ext.desc', 6423, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBK_20_Dohod/1.0/REF_KBK_20_Dohod.ext.desc']
# ['REF_KBKFKR.ext.desc', 5674, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBKFKR/1.0/REF_KBKFKR.ext.desc']
# ['EXP_DecisionTaxAuthority.desc', 34359, './exp-03-supp/Func/docs/sufd-services.EXP/setup/EXP_DecisionTaxAuthority/1.0/EXP_DecisionTaxAuthority.desc']
# ['EXP_REP_IMPL_ED.desc', 18581, './exp-03-supp/Func/docs/sufd-services.EXP/setup/EXP_REP_IMPL_ED/1.0/EXP_REP_IMPL_ED.desc']
# ['REF_Calendar.desc', 2370, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_Calendar/1.0/REF_Calendar.desc']
# ['REF_BAandPA.desc', 5038, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_BAandPA/1.0/REF_BAandPA.desc']
# ['REF_IPandKFH.desc', 8072, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_IPandKFH/1.0/REF_IPandKFH.desc']
# ['REF_KBK_AGROUP.ext.desc', 1922, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBK_AGROUP/1.0/REF_KBK_AGROUP.ext.desc']
# ['REF_Banks.ext.desc', 7479, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_Banks/1.0/REF_Banks.ext.desc']
# ['ARP_FAH_IndPersAcc.desc', 2091, './exp-03-supp/Func/docs/sufd-services.dicts/setup/ARP_FAH_IndPersAcc/1.0/ARP_FAH_IndPersAcc.desc']
# ['REF_KRKS.desc', 11522, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KRKS/1.0/REF_KRKS.desc']
# ['REF_KBK10.ext.desc', 2971, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_KBK10/1.0/REF_KBK10.ext.desc']
# ['REF_PersAccount.ext.desc', 5904, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_PersAccount/1.0/REF_PersAccount.ext.desc']
# ['REF_PersAccount.ext.desc', 18926, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_PersAccount/1.0/REF_PersAccount.ext.desc']
# ['REF_CasplanSym.desc', 1361, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_CasplanSym/1.0/REF_CasplanSym.desc']
# ['REF_BAandSVR.desc', 3911, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_BAandSVR/1.0/REF_BAandSVR.desc']
# ['REF_KBKCSR.ext.desc', 6151, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBKCSR/1.0/REF_KBKCSR.ext.desc']
# ['EXP_ProcessInfED.desc', 20076, './exp-03-supp/Func/docs/sufd-services.EXP/setup/EXP_ProcessInfED/1.0/EXP_ProcessInfED.desc']
# ['REF_PayAuthTypes.desc', 2709, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_PayAuthTypes/1.0/REF_PayAuthTypes.desc']
# ['MSC_TransCardMIRFL.desc', 43960, './exp-03-supp/Func/docs/sufd-services.EXP/setup/MSC_TransCardMIRFL/1.0/MSC_TransCardMIRFL.desc']
# ['REF_KBKGlava.ext.desc', 6033, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBKGlava/1.0/REF_KBKGlava.ext.desc']
# ['REF_UBPandNUBP.ext.desc', 55096, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_UBPandNUBP/1.0/REF_UBPandNUBP.ext.desc']
# ['REF_Budgets.ext.desc', 2353, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_Budgets/1.0/REF_Budgets.ext.desc']
# ['REF_FundSources.desc', 1740, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_FundSources/1.0/REF_FundSources.desc']
# ['REF_KBKVidIstoch.ext.desc', 2525, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBKVidIstoch/1.0/REF_KBKVidIstoch.ext.desc']
# ['REF_LegalActType.ext.desc', 981, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_LegalActType/1.0/REF_LegalActType.ext.desc']
# ['REF_LegalActType.ext.desc', 1026, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_LegalActType/1.0/REF_LegalActType.ext.desc']
# ['REF_SubCodeNUBP.desc', 2583, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_SubCodeNUBP/1.0/REF_SubCodeNUBP.desc']
# ['REF_TOFK.ext.desc', 2227, './exp-03-supp/Func/docs/sufd-services.CostManagement/setup/REF_TOFK/1.0/REF_TOFK.ext.desc']
# ['REF_KBKRvsBAK.desc', 2108, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBKRvsBAK/1.0/REF_KBKRvsBAK.desc']
# ['ARP_FAH_LISTPA.desc', 2050, './exp-03-supp/Func/docs/sufd-services.dicts/setup/ARP_FAH_LISTPA/1.0/ARP_FAH_LISTPA.desc']
# ['EXP_ProcessInfRNO.desc', 25119, './exp-03-supp/Func/docs/sufd-services.EXP/setup/EXP_ProcessInfRNO/1.0/EXP_ProcessInfRNO.desc']
# ['REF_KBKVidRashod.ext.desc', 5633, './exp-03-supp/Func/docs/sufd-services.dicts/setup/REF_KBKVidRashod/1.0/REF_KBKVidRashod.ext.desc']

# %% [markdown]
# ## Парсинг desc и подсчет кол-ва полей

# %%
# Тест среднего времени выполнения функции
# %timeit tuple(generator_xml_elements('migration'))
# Out:
# 87.8 ms ± 3.39 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Проверить отсутствие в списке
# DBD_Approval_Solution.desc -- calc_navigation_df('nav_to_full_copy')
# EXP_FAIP.ext.desc -- calc_navigation_df('to_manual_copy')
# compare_fields_count('the_same_fields_count').loc[lambda x: x.formular == 'DICT_BASE.desc']
print('Списки формуляров: с одинаковым числом полей')
print(compare_fields_count('the_same_fields_count').shape)
print('с разным числом полей')
print(compare_fields_count('have_diff').shape)
print()
print('из них полей больше у формуляров из мигрируемого проекта')
print(compare_fields_count('migration_have_big').shape)
print('из них полей больше у формуляров из гита')
print(compare_fields_count('git_have_big').shape)
# Out:
# Списки формуляров: с одинаковым числом полей
# (23, 3)
# с разным числом полей
# (17, 3)
#
# из них полей больше у формуляров из мигрируемого проекта
# (10, 3)
# из них полей больше у формуляров из гита
# (7, 3)

# %%
compare_fields_count('the_same_fields_count')
# Out:
#                       formular  fields_num_x  fields_num_y
# 1     REF_PersAccount.ext.desc            82            82
# 7    REF_OKATOtoOKTMO.ext.desc            24            24
# 14               REF_KRKS.desc            57            57
# 16     REF_KBK_30_Ist.ext.desc            32            32
# 18   REF_KBK_20_Dohod.ext.desc            42            42
# 21          REF_OKTMO.ext.desc            18            18
# 22   REF_KBKVidIstoch.ext.desc            16            16
# 24        REF_SubCodeNUBP.desc            16            16
# 26       REF_PayAuthTypes.desc            12            12
# 27         REF_CasplanSym.desc             6             6
# 28          REF_KBKRvsBAK.desc            11            11
# 30          REF_BankCards.desc            38            38
# 32      REF_NationProject.desc            16            16
# 34       REF_KBKGlava.ext.desc            46            46
# 37           REF_OKEI.ext.desc            18            18
# 40            REF_BAandPA.desc            21            21
# 42  REF_KBK_10_Rashod.ext.desc            29            29
# 43        REF_BankAccount.desc            46            46
# 44     REF_KBK_AGROUP.ext.desc            10            10
# 46            REF_CSandRC.desc            11            11
# 47        REF_KBKCCSS.ext.desc            23            23
# 48           REF_BAandSVR.desc            18            18
# 49        REF_FundSources.desc             8             8

# %%
# Реализовать проверку исключения дубликатов формуляров
# Список всех формуляров и их несовпадающих полей (Формуляр, {Поле1,Поле2})
tuple(
    compare_fields()
)

# %%
# Тестовая функция для получения списка отличающихся полей конкретного формуляра
def test1():
  for x in compare_fields():
    if x[0] == 'EXP_CaseED.desc':
      return x

# %%
test1()
# Out:
# ('EXP_CaseED.desc',
#  {'LA_MAIN_CODETOFK',
#   'LA_MAIN_COUNTED',
#   'LA_MAIN_CREATIONDATE',
#   'LA_MAIN_ISEDITBLOCK',
#   'LA_MAIN_NAMETOFK',
#   'LA_MAIN_NUMCASEED',
#   'SI_ACCESSLEVELSTEREOTYPE',
#   'SI_STATUS_DOC'})

# %%
# Тест сравнения названия полей в конкретном формуляре
# Если не работает, сделать тест, что конкретный формуляр есть в папке мигрируемого проекта и в папке гита 
df_compare_fields('REF_OKATOtoOKTMO.ext.desc')
# Out:
#                        0                1
# 5         OKTMOCODE_CODE        OKTMOCODE
# 6         OKTMOCODE_NAME    OKTMONAME2013
# 9   OKATOACTINGCODE_CODE  OKATOACTINGCODE
# 10  OKATOACTINGCODE_NAME  OKATOACTINGNAME
# 18    PARENTPPOCODE_CODE    PARENTPPOCODE

# %%
# Тест, что конкретный формуляр есть в папке мигрируемого проекта и в папке гита
simple_print_file_path('DBD_DepartMF_RF.desc')
# Out:
# ['DBD_DepartMF_RF.desc', 2821, './Func/docs/sufd-services.dicts/setup/DBD_DepartMF_RF/1.0/DBD_DepartMF_RF.desc']
# ['DBD_DepartMF_RF.desc', 2447, '../../exp-03-supp/Func/docs/sufd-services.dicts/setup/DBD_DepartMF_RF/1.0/DBD_DepartMF_RF.desc']

# %% [markdown]
# # Поиск и копирование ЖЦ

# %% [markdown]
# ## Результаты анализа

# %%
print('Списки жц: для копирования из мигрированного проекта')
print(prepare_lc_df('nav_to_copy','lc_to_copy').shape)
print('для копирования из бинарок, так как ЖЦ есть только в гите и нет в мигрируемом проекте')
print(prepare_lc_df('nav_to_copy','lc_to_find_in_binary').shape)
print('родительских ЖЦ')
print(prepare_lc_df('nav_to_copy','parent_lc').shape)

# %%
# Тест получения расположения файла ЖЦ
simple_print_lc_path('TOFKRegisterMonitor03_14_lc.lc')
# Out:
# ['TOFKRegisterMonitor03_14_lc.lc', 46551, './Func/config/lifecycles/TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc']
# ['TOFKRegisterMonitor03_14_lc.lc', 43950, '../../exp-03-supp/Func/config/lifecycles/TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc']

# %%
# Тест получения статусов конкретного ЖЦ
set(
    elems_attrib_generator(
      get_xml_root('path_generator', 'lc_state','lc', GIT_LC_DIR+'TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc')
))
# Out:
# {'CREATED', 'Formed'}

# %%
# Тест получения переходов конкретного ЖЦ
set(
    elems_attrib_generator(
      get_xml_root('path_generator', 'lc_transition','lc', MIG_LC_DIR+'TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc')
))
# Out:
# {'CreatedTOFKRegisterMonitoring',
#  'Testttttt',
#  'UpdateTOFKRegisterMonitoring',
#  'storeFromClientSaveFillings',
#  'storeFromWS'}

# %% [markdown]
# ## Получение студийной информации из статусов и переходов

# %% [markdown]
# Переход
# ```
#     <ns0:transition error-state="CREATED" id="storeFromClientSaveFillings" out-state="CREATED">
#       <ns0:description>Сохраняет документ, созданный вручную клиентом и сохраняет параметры заполнений</ns0:description>
#       <ns0:in-states>
#         <ns0:in-state>CREATED</ns0:in-state>
#       </ns0:in-states>
#       <ns0:action>
#         <ns0:call-ref id="storeFromClientCall">
#           <ns0:description>Сохранение документа</ns0:description>
#         </ns0:call-ref>
#       </ns0:action>
#     <ns2:bounds height="50" width="100" x="-133" y="-100" />
#     </ns0:transition>
# ```
# Статус
# ```
# <ns0:states>
#     <ns0:state system-name="CREATED">
#       <ns0:edit-policy attachments="false" />
#     <ns2:bounds height="75" width="75" x="0" y="0" />
#     </ns0:state>
# ```

# %%
# Тест получения списка переходов и атрибутов входящих/исходящих статусов перехода для конкретного ЖЦ
tuple(
    gen_instate(
        'lc_transition',
        GIT_LC_DIR+'TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc',
        MIG_LC_DIR+'TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc'
    )
)
# Out:
# ('storeFromClientSaveFillings',
#  ('CREATED', 'ffff00', 'instate'),
#  ('ADDED', '123456', 'instate'),
#  ('REGISTRED', 'ffff00', 'outstate'),
#  'CreatedTOFKRegisterMonitoring',
#  ('CREATED', 'ffff00', 'instate'),
#  'UpdateTOFKRegisterMonitoring',
#  'Testttttt',
#  'storeFromWS')

# %%
# Тест изменения ЖЦ: добавляются bounds к статусам и переходам у конкретного ЖЦ
add_bounds(GIT_LC_DIR+'TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc', 
           MIG_LC_DIR+'TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc')
# Тест удаления лишних пробелов из ЖЦ
del_whitespace(GIT_LC_DIR+'TOFKRegisterMonitor03_14_lc/TOFKRegisterMonitor03_14_lc.lc')

# %%
# Тест получения расположения файла ЖЦ
simple_print_lc_path('MSC_AccountTrans_lc.lc')
# Out:
# ['MSC_AccountTrans_lc.lc', 5366, './Func/config/lifecycles/MSC_AccountTrans_lc/MSC_AccountTrans_lc.lc']
# ['MSC_AccountTrans_lc.lc', 4798, '../../exp-03-supp/Func/config/lifecycles/MSC_AccountTrans_lc/MSC_AccountTrans_lc.lc']
